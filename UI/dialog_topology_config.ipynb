# %%
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *

# %%
class Ui_Dialog(object):
    def setup_ui(self, Dialog):
        if not Dialog.objectName():
            Dialog.setObjectName(u"Dialog")
        Dialog.resize(831, 612)
        self.gridLayout_2 = QGridLayout(Dialog)
        self.gridLayout_2.setObjectName(u"gridLayout_2")
        self.gridLayout = QGridLayout()
        self.gridLayout.setObjectName(u"gridLayout")
        self.groupBox_2 = QGroupBox(Dialog)
        self.groupBox_2.setObjectName(u"groupBox_2")
        font = QFont()
        font.setBold(True)
        font.setWeight(75)
        self.groupBox_2.setFont(font)
        self.groupBox_2.setAlignment(Qt.AlignCenter)
        self.gridLayout_4 = QGridLayout(self.groupBox_2)
        self.gridLayout_4.setObjectName(u"gridLayout_4")
        self.comboBox_activation_function_final = QComboBox(self.groupBox_2)
        self.comboBox_activation_function_final.setObjectName(u"comboBox_activation_function_final")
        font1 = QFont()
        font1.setBold(False)
        font1.setWeight(50)
        self.comboBox_activation_function_final.setFont(font1)

        self.gridLayout_4.addWidget(self.comboBox_activation_function_final, 1, 1, 1, 1)

        font2 = QFont()
        font2.setBold(False)
        font2.setItalic(True)
        font2.setWeight(50)

        self.label_4 = QLabel(self.groupBox_2)
        self.label_4.setObjectName(u"label_4")
        self.label_4.setFont(font2)
        self.label_4.setAlignment(Qt.AlignCenter)

        self.gridLayout_4.addWidget(self.label_4, 1, 0, 1, 1)

        self.gridLayout.addWidget(self.groupBox_2, 6, 0, 1, 1)

        self.groupBox_3 = QGroupBox(Dialog)
        self.groupBox_3.setObjectName(u"groupBox_3")
        self.groupBox_3.setFont(font)
        self.groupBox_3.setAlignment(Qt.AlignCenter)
        self.gridLayout_5 = QGridLayout(self.groupBox_3)
        self.gridLayout_5.setObjectName(u"gridLayout_5")
        self.verticalLayout_2 = QVBoxLayout()
        self.verticalLayout_2.setObjectName(u"verticalLayout_2")
        self.verticalSpacer_3 = QSpacerItem(20, 40, QSizePolicy.Minimum, QSizePolicy.Expanding)

        self.verticalLayout_2.addItem(self.verticalSpacer_3)

        self.label_5 = QLabel(self.groupBox_3)
        self.label_5.setObjectName(u"label_5")
        self.label_5.setFont(font2)
        self.label_5.setAlignment(Qt.AlignCenter)

        self.verticalLayout_2.addWidget(self.label_5)

        self.lineEdit_neuron_numbers_hidden = QLineEdit(self.groupBox_3)
        self.lineEdit_neuron_numbers_hidden.setObjectName(u"lineEdit_neuron_numbers_hidden")
        self.lineEdit_neuron_numbers_hidden.setFont(font1)

        self.verticalLayout_2.addWidget(self.lineEdit_neuron_numbers_hidden)

        self.label_6 = QLabel(self.groupBox_3)
        self.label_6.setObjectName(u"label_6")
        self.label_6.setFont(font2)
        self.label_6.setAlignment(Qt.AlignCenter)

        self.verticalLayout_2.addWidget(self.label_6)

        self.comboBox_activation_function_hidden = QComboBox(self.groupBox_3)
        self.comboBox_activation_function_hidden.setObjectName(u"comboBox_activation_function_hidden")
        self.comboBox_activation_function_hidden.setFont(font1)

        self.verticalLayout_2.addWidget(self.comboBox_activation_function_hidden)

        self.verticalSpacer = QSpacerItem(20, 40, QSizePolicy.Minimum, QSizePolicy.Expanding)

        self.verticalLayout_2.addItem(self.verticalSpacer)

        self.pushButton_add_hidden_layer = QPushButton(self.groupBox_3)
        self.pushButton_add_hidden_layer.setObjectName(u"pushButton_add_hidden_layer")
        font3 = QFont()
        font3.setBold(False)
        font3.setItalic(False)
        font3.setWeight(50)
        self.pushButton_add_hidden_layer.setFont(font3)
        self.pushButton_add_hidden_layer.setFlat(False)

        self.verticalLayout_2.addWidget(self.pushButton_add_hidden_layer)

        self.verticalSpacer_2 = QSpacerItem(20, 40, QSizePolicy.Minimum, QSizePolicy.Expanding)

        self.verticalLayout_2.addItem(self.verticalSpacer_2)


        self.gridLayout_5.addLayout(self.verticalLayout_2, 0, 0, 1, 1)

        self.tableView = QTableView(self.groupBox_3)
        self.tableView.setObjectName(u"tableView")
        self.tableView.setFont(font1)

        self.gridLayout_5.addWidget(self.tableView, 0, 1, 1, 1)


        self.gridLayout.addWidget(self.groupBox_3, 3, 0, 1, 1)


        self.gridLayout_2.addLayout(self.gridLayout, 0, 0, 1, 1)

        self.widget_topology_diagram = QWidget(Dialog)
        self.widget_topology_diagram.setObjectName(u"widget_topology_diagram")

        self.gridLayout_2.addWidget(self.widget_topology_diagram, 0, 1, 1, 1)

        self.pushButton_save_topology = QPushButton(Dialog)
        self.pushButton_save_topology.setObjectName(u"pushButton_save_topology")

        self.gridLayout_2.addWidget(self.pushButton_save_topology, 1, 0, 1, 1)

        self.horizontalLayout = QHBoxLayout()
        self.horizontalLayout.setObjectName(u"horizontalLayout")
        self.horizontalSpacer = QSpacerItem(40, 20, QSizePolicy.Expanding, QSizePolicy.Minimum)

        self.horizontalLayout.addItem(self.horizontalSpacer)

        self.pushButton_reset_topology = QPushButton(Dialog)
        self.pushButton_reset_topology.setObjectName(u"pushButton_reset_topology")

        self.horizontalLayout.addWidget(self.pushButton_reset_topology)

        self.horizontalSpacer_2 = QSpacerItem(40, 20, QSizePolicy.Expanding, QSizePolicy.Minimum)

        self.horizontalLayout.addItem(self.horizontalSpacer_2)


        self.gridLayout_2.addLayout(self.horizontalLayout, 1, 1, 1, 1)


        self.retranslate_ui(Dialog)
        self.input_validator()

        QMetaObject.connectSlotsByName(Dialog)

    def input_validator(self):

        validator_only_int = QIntValidator()

        self.lineEdit_neuron_numbers_hidden.setValidator(validator_only_int)
        
    #################################### Translater ####################################
        
    def retranslate_ui(self, Dialog):
        Dialog.setWindowTitle(QCoreApplication.translate("Dialog", u"Dialog", None))
        self.groupBox_2.setTitle(QCoreApplication.translate("Dialog", u"Capa de Salida", None))
        self.label_4.setText(QCoreApplication.translate("Dialog", u"Funci\u00f3n de Activaci\u00f3n", None))
        self.groupBox_3.setTitle(QCoreApplication.translate("Dialog", u"Capas Ocultas", None))
        self.label_5.setText(QCoreApplication.translate("Dialog", u"Numero de Neuronas", None))
        self.label_6.setText(QCoreApplication.translate("Dialog", u"Funci\u00f3n de Activaci\u00f3n", None))
        self.pushButton_add_hidden_layer.setText(QCoreApplication.translate("Dialog", u"Agregar Capa", None))
        self.pushButton_save_topology.setText(QCoreApplication.translate("Dialog", u"Guardar Topolog\u00eda", None))
        self.pushButton_reset_topology.setText(QCoreApplication.translate("Dialog", u"Reiniciar Topolog\u00eda", None))
